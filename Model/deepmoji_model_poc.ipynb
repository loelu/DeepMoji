# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from pipeline.prepare_data import prepare_data
from pipeline.model import create_model, fit
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# []

# %%
# downloading the dataset can take a while
x,y = prepare_data()

# %%
model = create_model()

# %%
fit(model, x, y)
# Out:
# 8/8 [==============================] - 49s 6s/step - loss: 24.0787 - acc: 0.0322 - val_loss: 0.7042 - val_acc: 0.4100

# %%
predict = model.predict(x[:1])

# %%
import matplotlib.pyplot as plt
plt.imshow(np.uint8(x[1]))
plt.scatter(predict[0][0::2], predict[0][1::2], c='Pink', marker='*')
plt.show()
